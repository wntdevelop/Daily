# %%
'''
# 2023_07_01

    # 2023_07_01_first
        # 06:00 ~ 12:00
            06:00 ~ 10:00 - zzZ
            10:00 ~ 12:00 - lunch
            
    # 2023_07_01_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - go_to_study_cafe
            13:00 ~ 15:00 - analyst_Sales
            15:00 ~ 18:00 - thesis_sorting
            
    # 2023_07_01_third
        # 18:00 ~ 24:00
            18:00 ~ 22:00 - thesis_reading
            22:00 ~ 24:00 - family_meet
            
    # 2023_07_01_fourth
        # 24:00 ~ 06:00
            00:00 ~ 03:00 - family_meet
            03:00 ~ 06:00 - zzZ
        
    # do_list
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study
        - CJG_meeting
        - thesis_sorting
        - thesis_reading
        - thesis_searching
'''

# %%
'''
# 2023_07_02

    # 2023_07_02_first
        # 06:00 ~ 12:00
            06:00 ~ 10:00 - zzZ
            10:00 ~ 12:00 - ready_and_breakfirst
            
    # 2023_07_02_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - go_to_cafe
            13:00 ~ 18:00 - thesis_presentation
            
    # 2023_07_02_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 22:00 - talk_with_honi
            22:00 ~ 24:00 - go_to_dormitory
            
    # 2023_07_02_fourth
        # 24:00 ~ 06:00
            00:00 ~ 03:00 - call_with_friend
            03:00 ~ 03:30 - plan
            03:30 ~ 06:00 - zzZ
            
    # do_list
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study
        - CJG_meeting
        - thesis_sorting
        - thesis_reading
        - thesis_searching
'''

# %%
'''
# 2023_07_03

    # 2023_07_03_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ
            
    # 2023_07_03_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - thesis_presentation
            13:00 ~ 14:00 - lunch
            14:00 ~ 18:00 - thesis_presentation
            
    # 2023_07_03_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - thesis_presentation
            
    # 2023_07_03_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
            
    # do_list
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study 
        - CJG_meeting
        - thesis_sorting
        - thesis_reading
        - thesis_searching
'''

# %%
'''
# 2023_07_04

    # 2023_07_04_first
        # 06:00 ~ 12:00
            06:00 ~ 08:00 - zzZ
            08:00 ~ 10:00 - take_a_rest
            10:00 ~ 12:00 - thesis_presentation

    # 2023_07_04_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - thesis_presentation
            
    # 2023_07_04_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - thesis_presentation
            
    # 2023_07_04_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
            
    # do_list
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study 
        - CJG_meeting
        - thesis_sorting
        - thesis_reading
        - thesis_searching
'''

# %%
'''
# 2023_07_05

    # 2023_07_05_first
        # 06:00 ~ 12:00
            06:00 ~ 08:00 - zzZ
            08:00 ~ 09:00 - plan_and_apply
            09:00 ~ 12:00 - E-puck_controller_modify

    # 2023_07_05_second
        # 12:00 ~ 18:00
            12:00 ~ 14:00 - lunch_with_HJM
            14:00 ~ 16:00 - E-puck_controller_modify
            16:00 ~ 18:00 - go_to_Anyang
            
    # 2023_07_05_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 22:00 - go_to_cafe_SSC
            22:00 ~ 24:00 - go_to_dormitory

    # 2023_07_05_fourth
        # 24:00 ~ 06:00
            00:00 ~ 04:00 - take_a_resk
            04:00 ~ 06:00 - zzZ
            
    # do_list
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study 
        - CJG_meeting
        - thesis_sorting
        - thesis_reading
        - thesis_searching
'''

# %%
'''
# 2023_07_06

    # 2023_07_06_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2023_07_06_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - RSS_ready
            
    # 2023_07_06_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - presentation_ready

    # 2023_07_06_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
            
    # do_list
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study 
        - CJG_meeting
        - thesis_sorting
        - thesis_reading
        - thesis_searching
'''

# %%
'''
# 2023_07_07

    # 2023_07_07_first
        # 06:00 ~ 12:00
            06:00 ~ 08:00 - zzZ
            08:00 ~ 12:00 - RSS_ready

    # 2023_07_07_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 16:00 - RSS_ready
            16:00 ~ 18:00 - AGH_meeting
            
    # 2023_07_07_third
        # 18:00 ~ 24:00
            18:00 ~ 22:00 - meet_KJL
            22:00 ~ 24:00 - go_to_home

    # 2023_07_07_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - talk_to_family
            02:00 ~ 06:00 - zzZ
            
            
    # do_list
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study 
        - CJG_meeting
        - thesis_sorting
        - thesis_reading
        - thesis_searching
'''

# %%
'''
# 2023_07_08

    # 2023_07_08_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2023_07_08_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - RSS_ready
            
    # 2023_07_08_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - dinner_family

    # 2023_07_08_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - talk_to_family
            02:00 ~ 06:00 - zzZ
            
            
    # do_list
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study 
        - CJG_meeting
        - thesis_sorting
        - thesis_reading
        - thesis_searching
'''

# %%
'''
# 2023_07_09

    # 2023_07_09_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2023_07_09_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - honi_meet
            
    # 2023_07_09_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - honi_meet

    # 2023_07_09_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ 
            
    # do_list
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study 
        - CJG_meeting
        - thesis_sorting
        - thesis_reading
        - thesis_searching
'''

# %%
'''
# 2023_07_10 ~ 2023_07_14

    RSS : Robotics : science and system
            
    # do_list
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study 
        - CJG_meeting
        - thesis_sorting
        - thesis_reading
        - thesis_searching
'''

# %%
'''
# 2023_07_15 ~ 2023_07_17

    Gangneung : trip with honi
            
    # do_list
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study 
        - CJG_meeting
        - thesis_sorting
        - thesis_reading
        - thesis_searching
'''

# %%
'''
# 2023_07_18

    # 2023_07_18_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 10:00 - day_plan
            10:00 ~ 12:00 - vocapod_day1
            
    # 2023_07_18_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 16:00 - curriculum_learning_meeting
            16:00 ~ 18:00 - muros_meeting
            
    # 2023_07_18_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - curriculum_learning_webots

    # 2023_07_18_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - take_a_rest 
            02:00 ~ 06:00 - zzZ 
            
            
    # do_list
        - NH-ORCA-c++
        - Portfolio_git
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study 
        - RSS : Robotics science and system review
        - two thesis per a week review
        - vocapod daily
        - journal_assessment_until Friday
'''

# %%
'''
# 2023_07_19

    # 2023_07_19_first
        # 06:00 ~ 12:00
            06:00 ~ 11:00 - zzZ
            11:00 ~ 12:00 - vocapod_day2
            
    # 2023_07_19_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - day_plan & breakfirst
            13:00 ~ 18:00 - curriculum_learning_code
            
    # 2023_07_19_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - journal_assessment

    # 2023_07_19_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ 
            
    # do_list
        - NH-ORCA-c++
        - Portfolio_git
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study 
        - RSS : Robotics science and system review
        - two thesis per a week review
        - vocapod daily
        - journal_assessment_until Friday
'''

# %%
'''
# 2023_07_20

    # 2023_07_20_first
        # 06:00 ~ 12:00
            06:00 ~ 10:00 - zzZ
            10:00 ~ 11:00 - vocapod_day2
            11:00 ~ 12:00 - RSS
            

    # 2023_07_20_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 16:00 - muros_presentation
            16:00 ~ 18:00 - muros_meeting

    # 2023_07_20_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - RSS

    # 2023_07_20_fourth
        # 24:00 ~ 06:00
            00:00 ~ 04:00 - RSS
            04:00 ~ 06:00 - zzZ
            
    # do_list
        - NH-ORCA-c++
        - Portfolio_git
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study 
        - RSS : Robotics science and system review
        - two thesis per a week review
        - vocapod daily
        - journal_assessment_until Friday
'''

# %%
'''
# 2023_07_21

    # 2023_07_21_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2023_07_21_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - RSS

    # 2023_07_21_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - RSS

    # 2023_07_21_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - RSS
            02:00 ~ 06:00 - zzZ
            
    # do_list
        - NH-ORCA-c++
        - Portfolio_git
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study 
        - RSS : Robotics science and system review
        - two thesis per a week review
        - vocapod daily
        - journal_assessment_until Friday
'''
