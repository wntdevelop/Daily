# %%
'''
# 2023_01_02

    # 2023_01_02_first
        # 06:00 ~ 12:00
            06:00 ~ 11:00 - rest_on_the_bed
            11:00 ~ 12:00 - ready_and_breakfirst
            

    # 2023_01_02_second
        # 12:00 ~ 18:00
            12:00 ~ 14:00 - opencv_study
            14:00 ~ 18:00 - AGH_laboratory

    # 2023_01_02_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - honina_date
          
    # 2023_01_02_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - English_plan
        - Neural_network_study
        - Battery_charger
        - Jeju_plan_plane_storage_food
        - 


'''

# %%
'''
# 2023_01_03

    # do_list
        - Graduate_school_search
        - English_plan
        - Neural_network_study
        - Battery_charger
        - Jeju_plan_plane_storage_food
        - 


'''

# %%
'''
# 2023_01_05

    # 2023_01_05_first
        # 06:00 ~ 12:00
            06:00 ~ 08:00 - zzZ
            08:00 ~ 09:00 - ready
            09:00 ~ 10:00 - take_a_rest
            10:00 ~ 11:00 - present_thinking
            11:00 ~ 12:00 - JeJu_plan
            
    # 2023_01_05_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - thesis_study
            
    # 2023_01_05_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 20:00 - thesis_study
            20:00 ~ 22:00 - Beeware_find
            22:00 ~ 23:00 - dormitory_apply
            23:00 ~ 24:00 - Beeware_find
            
    # 2023_01_05_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
            
    # do_list
        - Beeware_and_opencv
        - [2015+Volodymr]+Human-level control through deep reinforcement
        - [2016+Hado]+Deep Reinforcement Learning with Double Q-Learning
        - cs_study
        - Algorism_study
        - JeJu_plan
        - English_word_memorize
        - society
        - Application_for_classes_find_computer
        - career_consulting
        - QR_ordering_system_dev
        - moving_robot_dev
        -

'''

# %%
'''
# 2023_01_23 - Today I will try again. If i get up lately, i will get up 06:00. 

    # 2023_01_23_first
        # 06:00 ~ 12:00
            06:00 ~ 06:30 - day_plan
            06:30 ~ 07:00 - how to study english listening
            07:00 ~ 10:00 - study thesis
            10:00 ~ 12:00 - ready_to_honina
            
    # 2023_01_23_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 15:00 - shopping
            15:00 ~ 16:00 - smart store study
            16:00 ~ 18:00 - study thesis

    # 2023_01_23_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:00 - go dormitory
            21:00 ~ 22:00 - android dev
            22:00 ~ 23:00 - meeting LCW
            23:00 ~ 24:00 - study thesis
            
    # 2023_01_23_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
            
    # do_list
        - Android dev in java
        - Study two thesis
        - Study Cs
        - Study Algorism
        - JeJu plan
        - English word memorize
        - Study English listening 
        - Passionate society
        - Career certain
        - QR ordering system dev
        - Calling department office
        - Study github
        - Blog error solve

'''
