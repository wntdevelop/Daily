# %% [markdown]
# ### 2023년 5월 19일 다시 시작

# %%
'''
# 2023_05_19

    # 2022_05_19_first
        # 06:00 ~ 12:00
            06:00 ~ 10:35 - zzZ
            10:35 ~ 12:00 - cpu_scheduling_code

    # 2022_05_19_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - cpu_scheduling_code
            13:00 ~ 13:30 - lunch
            13:30 ~ 15:30 - real_stragegy && binary tree
            15:30 ~ 18:00 - cpu_scheduling_code
            
    # 2022_05_19_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 22:00 - cover_letter_lecture
            22:00 ~ 24:00 - total_design_seminar

    # 2022_05_19_fourth
        # 24:00 ~ 06:00
            00:00 ~ 05:00 - family_meet
            00:00 ~ 06:00 - zzZ
            
            
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_scheduling_algorithm
        - Cpu_shceduling_report
        - Total_design_seminar
        - Total_design_report
        - NH-ORCA
        - Git_collsiion_avoidance_code_push
        - Resume_present 
        - Binary_tree
        - Rss_register
        - Portfolio_git_(lotto_cpu_dqn_omok_website_aws_total_design)
        - data_struture_lecture
        - comento_vod
        - comento_project
'''

# %%
'''
# 2023_05_20

    # 2022_05_20_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2022_05_20_second
        # 12:00 ~ 18:00
            12:00 ~ 15:00 - data_struture_lecture
            15:00 ~ 18:00 - total_design_semiar
            
    # 2022_05_20_third
        # 18:00 ~ 24:00
            18:00 ~ 18:30 - dinner
            18:30 ~ 19:50 - total_design_semiar
            19:50 ~ 24:00 - cpu_scheduling_code

    # 2022_05_20_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - cpu_scheduling_code
            02:00 ~ 06:00 - zzZ
            
            
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - Total_design_report
        - NH-ORCA
        - Git_collsiion_avoidance_code_push
        - Resume_present
        - Binary_tree
        - Rss_register
        - Portfolio_git_(lotto_cpu_dqn_omok_website_aws_total_design)
        - comento_vod
        - comento_project
'''

# %%
'''
# 2023_05_21

    # 2022_05_21_first
        # 06:00 ~ 12:00
            06:00 ~ 08:30 - zzZ
            08:30 ~ 12:00 - date_with_honi
            

    # 2022_05_21_second
        # 12:00 ~ 18:00
            12:00 ~ 18:00 - date_with_honi
            
    # 2022_05_21_third
        # 18:00 ~ 24:00
            18:00 ~ 20:00 - date_with_honi
            20:00 ~ 24:00 - Data_structure_study

    # 2022_05_21_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
            
            
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - Total_design_report
        - NH-ORCA
        - Git_collsiion_avoidance_code_push
        - Resume_present
        - Binary_tree
        - Rss_register
        - Portfolio_git_(lotto_cpu_dqn_omok_website_aws_total_design)
        - comento_vod
        - comento_project
'''

# %%
'''
# 2023_05_22

    # 2022_05_22_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - zzZ
            07:00 ~ 07:30 - plan
            07:30 ~ 08:00 - Data_structure_study
            08:00 ~ 08:30 - breakfirst_1000won
            08:30 ~ 09:30 - Data_structure_study
            09:30 ~ 10:30 - ready
            10:30 ~ 12:00 - Data_structure_exam

    # 2022_05_22_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 14:00 - total_design_meeting
            14:00 ~ 17:00 - comento_project
            17:00 ~ 18:00 - dinner
           
    # 2022_05_22_third
        # 18:00 ~ 24:00
            18:00 ~ 21:00 - operating_system_lecture
            21:00 ~ 24:00 - comento_project

    # 2022_05_22_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
            
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - Total_design_report
        - NH-ORCA
        - Git_collsiion_avoidance_code_push
        - Resume_present_email_KTW
        - Binary_tree
        - Portfolio_git_(lotto_cpu_dqn_omok_website_aws_total_design)
        - comento_vod
        - comento_project
        - have haircut
        - CNN_train
        - 11_features_train
        - ANN_detail_ppt
        - presentation_script_write
'''

# %%
'''
# 2023_05_23

    # 2022_05_23_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - zzZ
            07:00 ~ 08:00 - comento_project
            08:00 ~ 08:30 - breakfirst_1000won
            08:30 ~ 10:00 - comento_project
            10:00 ~ 11:00 - zzZ 
            11:00 ~ 12:00 - comento_project
            

    # 2022_05_23_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - comento_project
           
    # 2022_05_23_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - github_study

    # 2022_05_23_fourth
        # 24:00 ~ 06:00
            00:00 ~ 00:30 - github_study
            00:30 ~ 06:00 - zzZ
            
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - Total_design_report
        - NH-ORCA
        - Git_collsiion_avoidance_code_push
        - Resume_present_email_KTW
        - Binary_tree
        - Portfolio_git_(lotto_cpu_dqn_omok_website_aws_total_design)
        - comento_vod
        - have haircut
        - CNN_train
        - 11_features_train
        - ANN_detail_ppt
        - presentation_script_write
'''

# %%
'''
# 2023_05_24

    # 2022_05_24_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - zzZ
            07:00 ~ 07:30 - plan
            07:30 ~ 08:00 - script_write
            08:00 ~ 08:30 - breakfirst_1000won
            08:30 ~ 10:00 - script_write
            10:00 ~ 12:00 - ORCA_code

    # 2022_05_24_second
        # 12:00 ~ 18:00
            12:30 ~ 13:30 - lunch
            13:30 ~ 15:30 - operating_system_tutor
            15:30 ~ 17:00 - ORCA_code
            17:00 ~ 18:00 - haircut
            
    # 2022_05_24_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 20:30 - rest
            20:30 ~ 22:30 - NH_ORCA
            22:30 ~ 24:00 - zzZ

    # 2022_05_24_fourth
        # 24:00 ~ 06:00
            00:00 ~ 03:30 - zzZ
            03:30 ~ 06:00 - NH_ORCA
            
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - Total_design_report
        - NH-ORCA
        - Git_collsiion_avoidance_code_push
        - Resume_present_email_KTW
        - Binary_tree
        - Portfolio_git_(lotto_cpu_dqn_omok_website_aws_total_design)
        - comento_vod
        - have haircut
        - CNN_train
        - 11_features_train
        - ANN_detail_ppt
        - presentation_script_write
'''

# %%
'''
# 2023_05_25

    # 2022_05_25_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 09:30 - ready
            09:30 ~ 11:30 - data_structure_lecture
            11:30 ~ 12:00 - muros_meeting

    # 2022_05_25_second
        # 12:00 ~ 18:00
            12:00 ~ 12:30 - muros_meeting
            12:30 ~ 13:30 - lunch
            13:30 ~ 15:30 - AI_lecture
            15:30 ~ 18:00 - total_design_presentation
            
    # 2022_05_25_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - total_design_presentation

    # 2022_05_25_fourth
        # 24:00 ~ 06:00
            00:00 ~ 01:00 - calling_friend
            01:00 ~ 06:00 - zzZ
            
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - Total_design_report
        - NH-ORCA-c++
        - Binary_tree
        - Portfolio_git
        - comento_vod
        - CNN_train
        - 11_features_train
        - ANN_detail_ppt
        - multi_tab_connect
        - make_poster
'''

# %%
'''
# 2023_05_26

    # 2022_05_26_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - zzZ
            07:00 ~ 07:10 - plan
            07:10 ~ 08:00 - total_design_presentation
            08:00 ~ 08:30 - breakfirst 1000 won
            08:30 ~ 12:00 - total_design_presentation

    # 2022_05_26_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 15:30 - real_strategy_lecture
            15:30 ~ 18:00 - total_design_presentation

    # 2022_05_26_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:00 - script_lecture
            21:00 ~ 23:00 - comento_lecture
            23:00 ~ 24:00 - honi_call

    # 2022_05_26_fourth
        # 24:00 ~ 06:00
            00:00 ~ 04:00 - honi_call
            04:00 ~ 06:00 - zzZ
            
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - Total_design_report
        - NH-ORCA-c++
        - Binary_tree
        - Portfolio_git
        - comento_vod
        - CNN_train
        - 11_features_train
        - ANN_detail_ppt
        - multi_tab_connect
        - make_poster
'''

# %%
'''
# 2023_05_27

    # 2022_05_27_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2022_05_27_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 16:00 - total_design_presentation
            16:00 ~ 18:00 - Cpu_shceduling_report

    # 2022_05_27_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - Cpu_shceduling_report

    # 2022_05_27_fourth
        # 24:00 ~ 06:00
            00:00 ~ 01:00 - total_design_meeting
            01:00 ~ 02:00 - comento_pdf_read
            

    # priority_do_list 
        - Data_structure_middle_exam
        - Total_design_presentation
        - Cpu_scheduling_video
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - NH-ORCA-c++
        - Binary_tree
        - Portfolio_git
        - comento_vod
        - multi_tab_connect
        - make_poster
'''

# %%
'''
# 2023_05_28

    # 2022_05_28_first
        # 06:00 ~ 12:00
            06:00 ~ 09:30 - zzZ
            09:30 ~ 10:30 - ready
            10:30 ~ 12:00 - honi_meet
            
    # 2022_05_28_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 16:00 - watch_movie
            16:00 ~ 18:00 - comento_pdf_read

    # 2022_05_28_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 22:00 - honi_cafe
            22:00 ~ 24:00 - comento_project_3
            
    # 2022_05_28_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:30 - comento_project_3
            02:30 ~ 06:00 - zzZ
            

    # priority_do_list
        - Data_structure_middle_exam
        - Total_design_presentation
        - Cpu_scheduling_video
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - NH-ORCA-c++
        - Binary_tree
        - Portfolio_git
        - comento_vod
        - multi_tab_connect
        - make_poster
'''

# %%
'''
# 2023_05_29

    # 2022_05_29_first
        # 06:00 ~ 12:00
            06:00 ~ 09:30 - zzZ
            09:30 ~ 10:00 - plan
            10:00 ~ 11:00 - comento_project_3
            11:00 ~ 12:00 - total_design_meeting
            
    # 2022_05_29_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 16:00 - total_design_ppt_modify
            16:00 ~ 18:00 - comento_project_3

    # 2022_05_29_third
        # 18:00 ~ 24:00
            18:00 ~ 21:00 - operating_system_lecture
            21:00 ~ 24:00 - take_a_rest
            
    # 2022_05_29_fourth
        # 24:00 ~ 06:00
            00:00 ~ 03:00 - honi_fight
            03:00 ~ 06:00 - zzZ

    # priority_do_list
        - Data_structure_middle_exam
        - Total_design_presentation
        - Cpu_scheduling_video
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - NH-ORCA-c++
        - Binary_tree
        - Portfolio_git
        - comento_vod
        - multi_tab_connect
        - make_poster
'''

# %%
'''
# 2023_05_30

    # 2022_05_30_first
        # 06:00 ~ 12:00
            06:00 ~ 08:30 - zzZ
            08:30 ~ 08:40 - plan
            08:40 ~ 11:00 - comento_project_3
            11:00 ~ 12:00 - lunch
            
    # 2022_05_30_second
        # 12:00 ~ 18:00
            12:00 ~ 15:00 - Binary_tree_c
            15:00 ~ 16:00 - File_input_output_c
            16:00 ~ 17:00 - String.h_c
            17:00 ~ 18:00 - Linked_list_c

    # 2022_05_30_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - Binary_tree_c
            
    # 2022_05_30_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - take_a_rest
            02:00 ~ 06:00 - zzZ

    # priority_do_list
        - Data_structure_middle_exam
        - Cpu_scheduling_video
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - NH-ORCA-c++
        - Binary_tree
        - Portfolio_git
        - comento_vod
        - multi_tab_connect
        - make_poster
'''

# %%
'''
# 2023_05_31

    # 2022_05_31_first
        # 06:00 ~ 12:00
            06:00 ~ 11:00 - zzZ
            11:00 ~ 12:00 - Binary_tree_c
            
    # 2022_05_31_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 15:00 - total_design_presentation
            15:00 ~ 18:00 - take_a_resk

    # 2022_05_31_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:00 - take_a_resk
            21:00 ~ 24:00 - Data_structure_study
            
    # 2022_05_31_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ

    # priority_do_list
        - Data_structure_middle_exam
        - Cpu_scheduling_video
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - NH-ORCA-c++
        - Binary_tree
        - Portfolio_git
        - comento_vod
        - multi_tab_connect
        - make_poster
'''
