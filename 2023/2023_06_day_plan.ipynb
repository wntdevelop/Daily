# %%
'''
# 2023_06_01

    # 2022_06_01_first
        # 06:00 ~ 12:00
            06:00 ~ 08:00 - make_poster
            08:00 ~ 08:30 - breakfast
            08:30 ~ 09:30 - make_poster
            09:30 ~ 11:30 - data_structure_lecture
            11:30 ~ 12:00 - lunch
            
            
    # 2022_06_01_second
        # 12:00 ~ 18:00
            12:00 ~ 14:00 - poster_make
            14:00 ~ 15:00 - hylive_lecture
            15:00 ~ 17:00 - make_poster
            17:00 ~ 18:00 - comento_project_4

    # 2022_06_01_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - comento_project_4
            
    # 2022_06_01_fourth
        # 24:00 ~ 06:00
            00:00 ~ 01:00 - call_mother
            01:00 ~ 06:00 - zzZ
            

    # priority_do_list
        - Data_structure_middle_exam
        - Cpu_scheduling_video
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
'''

# %%
'''
# 2023_06_02

    # 2022_06_02_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - zzZ
            07:00 ~ 08:00 - plan_and_comento
            08:00 ~ 08:30 - breakfast
            08:30 ~ 12:00 - comento_project_4
            
    # 2022_06_02_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 13:30 - comento_project_4
            13:30 ~ 15:30 - make_poster
            17:00 ~ 18:00 - comento_project_4

    # 2022_06_02_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - Cpu_scheduling_video
            
    # 2022_06_02_fourth
        # 24:00 ~ 06:00
            00:00 ~ 01:00 - call_mother
            01:00 ~ 06:00 - zzZ
            

    # priority_do_list
        - Data_structure_middle_exam
        - Cpu_scheduling_video
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
'''

# %%
'''
# 2023_06_03

    # 2022_06_03_first

        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ
            
    # 2022_06_03_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - zzZ
            13:00 ~ 14:00 - operating_system_study
            14:00 ~ 18:00 - comento_project_4

    # 2022_06_03_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - ready
            19:00 ~ 21:00 - go_home
            21:00 ~ 24:00 - dinner_with_family

    # 2022_06_03_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - dinner_with_family
            02:00 ~ 06:00 - zzZ

    # priority_do_list
        - Data_structure_middle_exam
        - Cpu_scheduling_video
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
'''

# %%
'''
# 2023_06_04

    # 2022_06_04_first

        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - Data_structure_study_with_honi
            
    # 2022_06_04_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - Data_structure_study_with_honi

    # 2022_06_04_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 22:00 - Data_structure_study_with_honi
            21:00 ~ 24:00 - go_my_home

    # 2022_06_04_fourth
        # 24:00 ~ 06:00
            00:00 ~ 01:00 - Data_structure_study
            01:00 ~ 06:00 - zzZ

    # priority_do_list
        - Data_structure_middle_exam
        - Cpu_scheduling_video
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
'''

# %%
'''
# 2023_06_05

    # 2022_06_05_first

        # 06:00 ~ 12:00
            06:00 ~ 08:00 - zzZ
            08:00 ~ 10:30 - Data_structure_study
            10:30 ~ 12:00 - Data_structure_exam
            
    # 2022_06_05_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 17:00 - take_a_resk
            17:00 ~ 18:00 - dinner
            

    # 2022_06_05_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - take_a_resk

    # 2022_06_05_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
'''

# %%
'''
# 2023_06_06

    # 2022_06_06_first

        # 06:00 ~ 12:00
            06:00 ~ 12:00 - take_a_resk
            
    # 2022_06_06_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - comento_project_4

    # 2022_06_06_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - comento_project_4

    # 2022_06_06_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - omok_coding
        - introduce_myself
'''

# %%
'''
# 2023_06_07

    # 2022_06_07_first

        # 06:00 ~ 12:00
            06:00 ~ 07:00 - zzZ
            07:00 ~ 08:00 - comento_project_4
            08:00 ~ 12:00 - introduce_myself
            
    # 2022_06_07_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - introduce_myself

    # 2022_06_07_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - introduce_myself

    # 2022_06_07_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - Data_structure_exam
        - Operating_system_exam
        - Cpu_shceduling_report
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - omok_coding
        - 선풍기 조립 후 사진
        - 포스터 참고하여 수정
        - 연구실에 포스터 통 있으니 거기다 넣어가삼
        - 포스터 출력 A0
'''

# %%
'''
# 2023_06_08

    # 2022_06_08_first

        # 06:00 ~ 12:00
            06:00 ~ 07:00 - zzZ
            07:00 ~ 12:00 - introduce_myself
            
    # 2022_06_08_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - introduce_myself

    # 2022_06_08_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:00 - introduce_myself
            21:00 ~ 24:00 - operating_system_study

    # 2022_06_08_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - omok_coding
        - 포스터 참고하여 수정
        - 연구실에 포스터 통 있으니 거기다 넣어가삼
        - 포스터 출력 A0
'''

# %%
'''
# 2023_06_09

    # 2022_06_09_first

        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2022_06_09_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 15:00 - real_strategy_lecture
            15:00 ~ 18:00 - omok_DRL
            
    # 2022_06_09_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:00 - introduce_myself_lecture
            21:00 ~ 23:00 - comento_lecture
            23:00 ~ 24:00 - omok_DRL
            
    # 2022_06_09_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - omok_coding
        - 포스터 참고하여 수정
        - 연구실에 포스터 통 있으니 거기다 넣어가삼
        - 포스터 출력 A0
'''

# %%
'''
# 2023_06_10

    # 2022_06_10_first

        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - poster_version2
            
    # 2022_06_10_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - poster_version2
            13:00 ~ 14:00 - operating_system_study
            14:00 ~ 15:00 - lunch
            15:00 ~ 18:00 - operating_system_study
            
    # 2022_06_10_third
        # 18:00 ~ 24:00
            18:00 ~ 20:00 - operating_system_study
            20:00 ~ 21:00 - dinner
            21:00 ~ 24:00 - operating_system_study
            
    # 2022_06_10_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - omok_coding
        - 연구실에 포스터 통 있으니 거기다 넣어가삼
        - 포스터 출력 A0
'''

# %%
'''
# 2023_06_11

    # 2022_06_11_first

        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - honi_data
            
    # 2022_06_11_second
        # 12:00 ~ 18:00
            12:00 ~ 18:00 - honi_data_with_study
            
    # 2022_06_11_third
        # 18:00 ~ 24:00
            18:00 ~ 22:00 - honi_data_with_study
            22:00 ~ 24:00 - operating_system_study
            
    # 2022_06_11_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - omok_coding
        - 연구실에 포스터 통 있으니 거기다 넣어가삼
        - 포스터 출력 A0
'''

# %%
'''
# 2023_06_12

    # 2022_06_12_first

        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - operating_system_study
            
    # 2022_06_12_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 15:00 - total_design_meeting
            15:00 ~ 18:00 - operating_system_study
            
    # 2022_06_12_third
        # 18:00 ~ 24:00
            18:00 ~ 20:00 - operating_system_exam
            20:00 ~ 21:00 - dinner
            21:00 ~ 24:00 - poster_presentation_ready
            
    # 2022_06_12_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - omok_coding
        - 연구실에 포스터 통 있으니 거기다 넣어가삼
        - 포스터 출력 A0
'''

# %%
'''
# 2023_06_13

    # 2022_06_13_first

        # 06:00 ~ 12:00
            06:00 ~ 08:00 - zzZ
            08:00 ~ 09:00 - administrative_building_visit
            09:00 ~ 12:00 - honi_meet
            
    # 2022_06_13_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 15:00 - movie
            15:00 ~ 18:00 - study_with_honi
            
    # 2022_06_13_third
        # 18:00 ~ 24:00
            18:00 ~ 20:00 - dinner
            20:00 ~ 21:00 - plan_with_honi
            21:00 ~ 22:00 - study_with_honi
            22:00 ~ 24:00 - go_to_dormitory
            
            
    # 2022_06_13_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - omok_coding
        - 연구실에 포스터 통 있으니 거기다 넣어가삼
        - 포스터 출력 A0
'''

# %%
'''
# 2023_06_14

    # 2022_06_14_first

        # 06:00 ~ 12:00
            06:00 ~ 07:30 - zzZ
            07:30 ~ 08:00 - plan
            08:00 ~ 12:00 - data_structure_study
            
    # 2022_06_14_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 14:00 - poster_presentation
            14:00 ~ 16:00 - AGH_meeting
            16:00 ~ 18:00 - data_structure_study
            
    # 2022_06_14_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - data_structure_study
            
    # 2022_06_14_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - omok_coding
        - 연구실에 포스터 통 있으니 거기다 넣어가삼
        - 포스터 출력 A0
'''

# %%
'''
# 2023_06_15

    # 2022_06_15_first

        # 06:00 ~ 12:00
            06:00 ~ 08:00 - zzZ
            08:00 ~ 08:30 - breakfirst
            08:30 ~ 10:00 - data_structure_study
            10:00 ~ 12:00 - data_structure_exam
            
    # 2022_06_15_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 17:00 - poster_presentation_modify
            17:00 ~ 18:00 - real_strategy_final_project
            
            
    # 2022_06_15_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - real_strategy_final_project
            
    # 2022_06_15_fourth
        # 24:00 ~ 06:00
            00:00 ~ 03:00 - real_strategy_final_project
            03:00 ~ 06:00 - zzZ

    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - omok_coding
        - 연구실에 포스터 통 있으니 거기다 넣어가삼
        - 포스터 출력 A0
        - real_strategy_final_project
        - total_design_presentation
        - AGH_meeting
        - vacation_plan

'''

# %%
'''
# 2023_06_16

    # 2022_06_16_first

        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ
            
    # 2022_06_16_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 14:00 - real_strategy_final_project
            14:00 ~ 18:00 - omok_program
            
    # 2022_06_16_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - omok_program
            
    # 2022_06_16_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - omok_coding
        - 연구실에 포스터 통 있으니 거기다 넣어가삼
        - 포스터 출력 A0
        - total_design_presentation
        - AGH_meeting
        - vacation_plan
'''

# %%
'''
# 2023_06_17

    # 2022_06_17_first

        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - poster
            
    # 2022_06_17_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 15:00 - plan_Gangneung
            15:00 ~ 18:00 - omok_program
            
    # 2022_06_17_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - omok_program
            
    # 2022_06_17_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - omok_coding
        - 연구실에 포스터 통 있으니 거기다 넣어가삼
        - 포스터 출력 A0
        - total_design_presentation
        - AGH_meeting
        - vacation_plan
'''

# %%
'''
# 2023_06_18

    # 2022_06_18_first

        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - honi_data
            
    # 2022_06_18_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - honi_data
            
    # 2022_06_18_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 22:00 - honi_data
            22:00 ~ 24:00 - final_exam_study
            
    # 2022_06_18_fourth
        # 24:00 ~ 06:00
            00:00 ~ 03:00 - final_exam_study
            03:00 ~ 06:00 - zzZ           
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - omok_coding
        - 연구실에 포스터 통 있으니 거기다 넣어가삼
        - 포스터 출력 A0
        - total_design_presentation
        - AGH_meeting
        - vacation_plan
'''

# %%
'''
# 2023_06_19

    # 2023_06_19_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - final_exam_datastructure
            
    # 2023_06_19_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 14:00 - AGH_meeting
            14:00 ~ 15:00 - poster_output
            15:00 ~ 18:00 - data_structure_omok_report
            
    # 2023_06_19_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:00 - go_to_home
            21:00 ~ 24:00 - family_data
            
    # 2023_06_19_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - family_data
            02:00 ~ 06:00 - play_game_with_CDG          
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
'''

# %%
'''
# 2023_06_20

    # 2023_06_20_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ
            
    # 2023_06_20_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 15:00 - Gangneung_plan
            15:00 ~ 18:00 - what_is_internet
            
    # 2023_06_20_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - what_is_internet
            19:00 ~ 24:00 - family_data
            
    # 2023_06_20_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
'''

# %%
'''
# 2023_06_21

    # 2023_06_21_first
        # 06:00 ~ 12:00
            06:00 ~ 08:00 - breakfirst & ready
            08:00 ~ 12:00 - go_to_society  
            
    # 2023_06_21_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - society_ICROS
            
    # 2023_06_21_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - take_a_rest
            
    # 2023_06_21_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
'''

# %%
'''
# 2023_06_22

    # 2023_06_22_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - breakfirst & ready
            
    # 2023_06_22_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - poster_presentation
            
    # 2023_06_22_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - take_a_rest
            
    # 2023_06_22_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
'''

# %%
'''
# 2023_06_23

    # 2023_06_23_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ
            
    # 2023_06_23_second
        # 12:00 ~ 18:00
            12:00 ~ 14:00 - lunch
            14:00 ~ 18:00 - go_to_domitary
            
    # 2023_06_23_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - take_a_rest
            
    # 2023_06_23_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
'''

# %%
'''
# 2023_06_24

    # 2023_06_24_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - go_to_home
            07:00 ~ 10:00 - zzZ
            10:00 ~ 12:00 - bakend_study
                       
    # 2023_06_24_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 15:00 - go_to_car_center_to_watch_car
            15:00 ~ 18:00 - bakend_study
            
    # 2023_06_24_third
        # 18:00 ~ 24:00
            18:00 ~ 20:00 - dinner
            20:00 ~ 24:00 - family_data
            
    # 2023_06_24_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - 하이패스 영수증
        - 경기지역화페_카드
        - 짐 차에 옮기기
        - Bakend_dev_study
        - CJG_meeting
        - AGU_meeting_Monday
        - have_hair_cut
'''

# %%
'''
# 2023_06_25

    # 2023_06_25_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - honi_data_The_HD_Seoul
                       
    # 2023_06_25_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 15:00 - honi_data_The_HD_Seoul
            15:00 ~ 18:00 - honi_data_Hangang River
            
    # 2023_06_25_third
        # 18:00 ~ 24:00
            18:00 ~ 20:00 - dinner
            20:00 ~ 24:00 - honi_data
            
    # 2023_06_25_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - 하이패스 영수증
        - 경기지역화페_카드
        - 짐 차에 옮기기
        - Bakend_dev_study
        - CJG_meeting
        - AGU_meeting_Monday
        - have_hair_cut
'''

# %%
'''
# 2023_06_26

    # 2023_06_26_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ
                       
    # 2023_06_26_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 15:00 - TOEIC_plan
            15:00 ~ 16:00 - AGH_meeting
            16:00 ~ 18:00 - Journal_outline
            
    # 2023_06_26_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:00 - TOEIC_plan
            21:00 ~ 24:00 - Journal_outline
            
    # 2023_06_26_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - ROS2_study
            02:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - 하이패스 영수증
        - 경기지역화페_카드
        - 짐 차에 옮기기
        - Bakend_dev_study
        - CJG_meeting
        - AGU_meeting_Monday
        - have_hair_cut
'''

# %%
'''
# 2023_06_27

    # 2023_06_27_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - Total_design
                       
    # 2023_06_27_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 17:00 - Journal_study
            17:00 ~ 18:00 - KSI_consult
            
    # 2023_06_27_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 20:00 - Journal_study
            20:00 ~ 24:00 - TOEIC_study
            
    # 2023_06_27_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - take_a_rest
            02:00 ~ 06:00 - zzZ
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study
        - CJG_meeting
        - have_hair_cut
'''

# %%
'''
# 2023_06_28

    # 2023_06_28_first
        # 06:00 ~ 12:00
            06:00 ~ 08:30 - zzZ
            08:30 ~ 09:00 - plan
            09:00 ~ 10:30 - sourcetree_study
            10:30 ~ 11:00 - ready
            11:00 ~ 12:00 - hair_cut
            
    # 2023_06_28_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 16:00 - Journal_study
            16:00 ~ 18:00 - Muros_meeting
            
    # 2023_06_28_third
        # 18:00 ~ 24:00
            18:00 ~ 20:00 - get-together
            20:00 ~ 24:00 - Journal_study
            
    # 2023_06_28_fourth
        # 24:00 ~ 06:00
            00:00 ~ 04:00 - talk_with_HGG
            04:00 ~ 06:00 - zzZ
            
        
    # do_list
        - English_plan
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study
        - CJG_meeting
        - have_hair_cut
'''

# %%
'''
# 2023_06_29

    # 2023_06_29_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ
            
    # 2023_06_29_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - Journal_study
            
    # 2023_06_29_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 20:00 - aws_lambda_study
            20:00 ~ 22:00 - TOIEC_study
            22:00 ~ 24:00 - Journal_study
            
    # 2023_06_29_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
        
    # do_list
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study
        - CJG_meeting
'''

# %%
'''
# 2023_06_30

    # 2023_06_30_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - zzZ
            07:00 ~ 09:00 - ready_honi_meet
            09:00 ~ 12:00 - study_cafe

    # 2023_06_30_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - take_a_rest
            
    # 2023_06_30_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - take_a_rest
            19:00 ~ 21:00 - dinner
            21:00 ~ 22:00 - go_to_home
            22:00 ~ 24:00 - family_date
            
    # 2023_06_30_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - family_date
            02:00 ~ 06:00 - zzZ
            
    # do_list
        - Web_server_vocapod
        - NH-ORCA-c++
        - Portfolio_git
        - comento_vod
        - total_design_presentation
        - vacation_plan
        - Bakend_dev_study
        - CJG_meeting
'''
