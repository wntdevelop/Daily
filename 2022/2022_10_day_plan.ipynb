# %%
'''
# 2022_10_01

    # 2022_10_01_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2022_10_01_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 15:00 - linux_dual_booting
            15:00 ~ 18:00 - play_game

    # 2022_10_01_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - go_to_home
            19:00 ~ 24:00 - drink_with_CDG
            

    # 2022_10_01_fourth
        # 24:00 ~ 06:00
            24:00 ~ 05:00 - drink_with_CDG
            05:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - tire_wear_predict_human_NN_study
        - support_vector_regresstion_learning
        - multiple_layer_perceptron_learning
        - Back_propagation_learning
        - smart_phone_modeling
        - LOS_download
        - webot_e_puch_study

'''

# %%
'''
# 2022_10_02

    # 2022_10_02_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2022_10_02_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 16:00 - linux_usage_study
            16:00 ~ 18:00 - help_parents

    # 2022_10_02_third
        # 18:00 ~ 24:00
            18:00 ~ 22:00 - help_parents
            22:00 ~ 24:00 - drink_parents
            

    # 2022_10_02_fourth
        # 24:00 ~ 06:00
            24:00 ~ 04:00 - drink_parents
            04:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - tire_wear_predict_human_NN_study
        - support_vector_regresstion_learning
        - multiple_layer_perceptron_learning
        - Back_propagation_learning
        - smart_phone_modeling
        - LOS_download
        - webot_e_puch_study

'''

# %%
'''
# 2022_10_03

    # 2022_10_03_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2022_10_03_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 15:00 - take_a_rest
            15:00 ~ 18:00 - support_vector_machine_study
            

    # 2022_10_03_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - linux_usage_study
            19:00 ~ 20:00 - dinner
            20:00 ~ 21:00 - go_to_school
            21:00 ~ 23:00 - support_vector_machine_study
            23:00 ~ 24:00 - total_design_meeting
            
    # 2022_10_03_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - tire_wear_predict_human_NN_study
        - support_vector_regresstion_learning
        - multiple_layer_perceptron_learning
        - Back_propagation_learning
        - smart_phone_modeling
        - LOS_download
        - webot_e_puch_study
        - find_adapter_research_room

'''

# %%
'''
# 2022_10_04

    # 2022_10_04_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 10:00 - Auto_meeting
            10:00 ~ 12:00 - linux_usage_study


    # 2022_10_04_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 14:30 - total_design_lecture
            14:30 ~ 18:00 - korea_literature_lecture
            

    # 2022_10_04_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - nahoni_meet
            
    # 2022_10_04_fourth
        # 24:00 ~ 06:00
            24:00 ~ 03:00 - nahoni_meet
            03:00 ~ 06:00 - zzZ
            
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - tire_wear_predict_human_NN_study
        - support_vector_regresstion_learning
        - multiple_layer_perceptron_learning
        - Back_propagation_learning
        - smart_phone_modeling
        - LOS_download
        - webot_e_puch_study
        - find_adapter_research_room
        - 3D_modeling_smart_phone

'''

# %%
'''
# 2022_10_05

    # 2022_10_05_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - car_research


    # 2022_10_05_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - car_research
            

    # 2022_10_05_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - university_festival
            
    # 2022_10_05_fourth
        # 24:00 ~ 06:00
            24:00 ~ 03:00 - university_festival
            03:00 ~ 06:00 - zzZ
            
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - tire_wear_predict_human_NN_study
        - support_vector_regresstion_learning
        - multiple_layer_perceptron_learning
        - Back_propagation_learning
        - smart_phone_modeling
        - LOS_download
        - webot_e_puch_study
        - find_adapter_research_room
        - 3D_modeling_smart_phone

'''

# %%
'''
# 2022_10_06

    # 2022_10_06_first
        # 06:00 ~ 12:00
            06:00 ~ 09:30 - zzZ
            09:30 ~ 12:30 - optimization_design_lecture


    # 2022_10_06_second
        # 12:00 ~ 18:00
            12:30 ~ 13:30 - lunch
            13:30 ~ 15:00 - AGH_meeting
            15:00 ~ 18:00 - honina_meet
            

    # 2022_10_06_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - do_list_conduct
            
    # 2022_10_06_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - honina_meet
            
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - tire_wear_predict_human_NN_study
        - support_vector_regresstion_learning
        - multiple_layer_perceptron_learning
        - Back_propagation_learning
        - smart_phone_modeling
        - webot_e_puch_study
        - find_adapter_research_room
        - 3D_modeling_smart_phone
        - sound_effect_email_send
        - korea_literature_project
        - optimization_lecture_watch

'''

# %%
'''
# 2022_10_07

    # 2022_10_07_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - car_research

    # 2022_10_07_second
        # 12:00 ~ 18:00
            12:00 ~ 14:00 - take_a_rest
            14:00 ~ 18:00 - car_research

    # 2022_10_07_third
        # 18:00 ~ 24:00
            18:00 ~ 20:00 - car_research
            20:00 ~ 24:00 - go_to_home
            
    # 2022_10_07_fourth
        # 24:00 ~ 06:00
            24:00 ~ 01:00 - family_time
            01:00 ~ 06:00 - zzZ
            
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - tire_wear_predict_human_NN_study
        - support_vector_regresstion_learning
        - multiple_layer_perceptron_learning
        - Back_propagation_learning
        - smart_phone_modeling
        - webot_e_puch_study
        - find_adapter_research_room
        - 3D_modeling_smart_phone
        - sound_effect_email_send
        - korea_literature_project
        - optimization_lecture_watch

'''

# %%
'''
# 2022_10_08

    # 2022_10_08_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - family_travel

    # 2022_10_08_second
        # 12:00 ~ 18:00
            12:00 ~ 18:00 - family_travel

    # 2022_10_08_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - family_travel
            
    # 2022_10_08_fourth
        # 24:00 ~ 06:00
            24:00 ~ 04:00 - family_travel
            04:00 ~ 06:00 - zzZ
            
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - tire_wear_predict_human_NN_study
        - support_vector_regresstion_learning
        - multiple_layer_perceptron_learning
        - Back_propagation_learning
        - smart_phone_modeling
        - webot_e_puch_study
        - find_adapter_research_room
        - 3D_modeling_smart_phone
        - sound_effect_email_send
        - korea_literature_project
        - optimization_lecture_watch

'''

# %%
'''
# 2022_10_09

    # 2022_10_09_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - family_travel

    # 2022_10_09_second
        # 12:00 ~ 18:00
            12:00 ~ 14:00 - go_to_home
            14:00 ~ 18:00 - honina_meet

    # 2022_10_09_third
        # 18:00 ~ 24:00
            18:00 ~ 23:00 - honina_meet
            23:00 ~ 24:00 - family_with_dinner
            
    # 2022_10_09_fourth
        # 24:00 ~ 06:00
            24:00 ~ 03:00 - family_with_dinner
            03:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - tire_wear_predict_human_NN_study
        - support_vector_regresstion_learning
        - multiple_layer_perceptron_learning
        - Back_propagation_learning
        - smart_phone_modeling
        - webot_e_puch_study
        - find_adapter_research_room
        - 3D_modeling_smart_phone
        - sound_effect_email_send
        - korea_literature_project
        - optimization_lecture_watch

'''

# %%
'''
# 2022_10_10

    # 2022_10_10_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - family_travel

    # 2022_10_10_second
        # 12:00 ~ 18:00
            12:00 ~ 18:00 - family_travel

    # 2022_10_10_third
        # 18:00 ~ 24:00
            18:00 ~ 20:00 - family_business_help
            20:00 ~ 22:00 - go_to_school
            22:00 ~ 24:00 - korea_literature_project
            
            
    # 2022_10_10_fourth
        # 24:00 ~ 06:00
            24:00 ~ 02:00 - honina_kakaotalk
            03:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - tire_wear_predict_human_NN_study
        - multiple_layer_perceptron_learning
        - Back_propagation_learning
        - webot_e_puch_study
        - 3D_modeling_smart_phone
        - sound_effect_email_send_CJG
        - optimization_lecture_watch   

'''

# %%
'''
# 2022_10_11

    # 2022_10_11_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - KTW_meeting_ready
            09:00 ~ 10:00 - Auto_meeting
            10:00 ~ 12:00 - KTW_meeting_ready
            
    # 2022_10_11_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 13:30 - KTW_meeting_ready
            13:30 ~ 14:30 - total_design_meeting
            14:30 ~ 17:30 - korea_literature_lecture
            17:30 ~ 18:00 - ros_and_webbot_study
            

    # 2022_10_11_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:00 - golf_lecture
            22:00 ~ 24:00 - honina_with_study_and_food
            
            
    # 2022_10_11_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - tire_wear_predict_human_NN_study
        - multiple_layer_perceptron_learning
        - Back_propagation_learning
        - webot_e_puch_study
        - 3D_modeling_smart_phone_~Friday
        - sound_effect_email_send_CJG
        - optimization_lecture_watch   
        - CJG_kakaotalk_need_document
        - total_design_meeting_ready
        - belt_load_cell_call
        -

'''

# %%
'''
# 2022_10_12

    # 2022_10_12_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - car_research
            
            
    # 2022_10_12_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - car_research
            

    # 2022_10_12_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:00 - golf_lecture
            22:00 ~ 24:00 - honina_with_study_and_food
            
            
    # 2022_10_12_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - webot_e_puch_study
        - 3D_modeling_smart_phone_~Friday
        - optimization_lecture_watch   
        - total_design_meeting_ready
        -

'''

# %%
'''
# 2022_10_13

    # 2022_10_13_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ
            
    # 2022_10_13_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - play_with_honina

    # 2022_10_13_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:00 - GST_university_festival
            21:00 ~ 24:00 - honina_with_zzZ
            
    # 2022_10_13_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - webot_e_puch_study
        - 3D_modeling_smart_phone_~Friday
        - optimization_lecture_watch   
        - total_design_meeting_ready
        -

'''

# %%
'''
# 2022_10_14

    # 2022_10_14_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - car_research
            
            
    # 2022_10_14_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - car_research
            

    # 2022_10_14_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:00 - CJG_meeting
            22:00 ~ 24:00 - CJG_project_ppt_make
            
            
    # 2022_10_14_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - webot_e_puch_study
        - 3D_modeling_smart_phone_~Friday
        - optimization_lecture_watch   
        - total_design_meeting_ready
        -

'''

# %%
'''
# 2022_10_15

    # 2022_10_15_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ
            
            
    # 2022_10_15_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - sleep_happy
            13:00 ~ 14:00 - ready
            14:00 ~ 18:00 - honina_meet
    
    # 2022_10_15_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - study_with_honina
            
    # 2022_10_15_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - webot_e_puch_study
        - 3D_modeling_smart_phone_~Friday
        - optimization_lecture_watch   
        - total_design_meeting_ready
        - korea_literature_project
        - optimization_lecture_study

'''

# %%
'''
# 2022_10_16 ~ 2022_10_26

    # test_study_and_wander_so_plan_no
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - webot_e_puch_study
        - 3D_modeling_smart_phone_~Friday
        - optimization_lecture_watch   
        - total_design_meeting_ready
        - korea_literature_project
        - optimization_lecture_study

'''
