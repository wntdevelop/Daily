# %%
'''
# 2022_11_01

    # 2022_11_01_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 10:00 - Linear_lecture_H
            19:00 ~ 12:00 - Neural_Network_lecture_H
            

    # 2022_11_01_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - coding_neural_network

    # 2022_11_01_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - honina_date
          
    # 2022_11_01_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - tire_wear_predict_human_NN_study
        - support_vector_regresstion_learning
        - multiple_layer_perceptron_learning
        - Back_propagation_learning
        - smart_phone_modeling
        - LOS_download
        - webot_e_puch_study
        - find_adapter_research_room
        - 3D_modeling_case_top_and_bottom
        - wireless_len_get
        - 각 교수님들께 말씀드리기
        - 나현이한테 말하기 (회식, 400일, 금요일, 입원 날짜, MRI)
        - 최적설계 강의듣기
        - ROS 어떻게 하는 지 공부하기
        - 인공신경망 강의 듣기 (혁펜하임)
        - 선형대수 강의 듣기 (혁펜하임)
        - kakaotalk_profile_change


'''

# %%
'''
# 2022_11_02

    # 2022_11_02_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - honina_date
            

    # 2022_11_02_second
        # 12:00 ~ 18:00
            12:00 ~ 18:00 - honina_date

    # 2022_11_02_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - honina_date
          
    # 2022_11_02_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - tire_wear_predict_human_NN_study
        - support_vector_regresstion_learning
        - multiple_layer_perceptron_learning
        - Back_propagation_learning
        - smart_phone_modeling
        - LOS_download
        - webot_e_puch_study
        - find_adapter_research_room
        - 3D_modeling_case_top_and_bottom
        - wireless_len_get
        - 각 교수님들께 말씀드리기
        - 나현이한테 말하기 (회식, 400일, 금요일, 입원 날짜, MRI)
        - 최적설계 강의듣기
        - ROS 어떻게 하는 지 공부하기
        - 인공신경망 강의 듣기 (혁펜하임)
        - 선형대수 강의 듣기 (혁펜하임)
        - kakaotalk_profile_change


'''

# %%
'''
# 2022_11_03

    # 2022_11_03_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - take_a_rest
            

    # 2022_11_03_second
        # 12:00 ~ 18:00
            12:00 ~ 18:00 - Neural_Network_study

    # 2022_11_03_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - honina_date
          
    # 2022_11_03_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - ansys_and_pneumatic_study
        - tire_wear_predict_human_NN_study
        - support_vector_regresstion_learning
        - multiple_layer_perceptron_learning
        - Back_propagation_learning
        - smart_phone_modeling
        - LOS_download
        - webot_e_puch_study
        - find_adapter_research_room
        - 3D_modeling_case_top_and_bottom
        - wireless_len_get
        - 각 교수님들께 말씀드리기
        - 나현이한테 말하기 (회식, 400일, 금요일, 입원 날짜, MRI)
        - 최적설계 강의듣기
        - ROS 어떻게 하는 지 공부하기
        - 인공신경망 강의 듣기 (혁펜하임)
        - 선형대수 강의 듣기 (혁펜하임)
        - kakaotalk_profile_change
'''

# %%
'''
# 2022_11_04 ~ 2022_11_09

    # 2022_10_29
        - there is a car accident

    # 2022_10_31 ~ 2022_11_09
        - hospitalization_start

    # 2022_11_09
        - hospitalization_finish
            
    # do_list
        - Graduate_school_search
        - english_plan
        - tire_wear_predict_human_NN_study
        - how_to_smart_phone_modeling
        - webot_e_puch_study
        - optimization_lecture_listen
        - how to connect with ros,webots,python
        - hyukpenhime_lecture
        - Busan_travling_plan
        - famliy_traviling_plan
        - CJG_checking_list_write
        - CJG_mmet
        - send_money_870,000_to_mom
        - PYS_meeting
        - total_design_meeting
        - buy_the_clothes_for_Busan
        

'''

# %%
'''
# 2022_11_10

    # 2022_11_10_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 12:00 - optimization_lecture
            

    # 2022_11_10_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 15:00 - AGH_meeting
            15:00 ~ 16:00 - CJG_checking_list_write
            16:00 ~ 18:00 - ros_study        


    # 2022_11_10_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 20:00 - Busan_plan_complete
            20:00 ~ 24:00 - ros_study
          

    # 2022_11_10_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - tire_wear_predict_human_NN_study
        - smart_phone_modeling_case_body_speaker
        - webot_e_puch_study
        - optimization_lecture_listen
        - how to connect with ros,webots,python
        - hyukpenhime_lecture
        - Busan_travling_plan
        - famliy_traviling_plan
        - CJG_checking_list_write
        - CJG_mmet
        - send_money_870,000_to_mom
        - PYS_meeting
        - total_design_meeting
        - buy_the_clothes_for_Busan
        - when_do_we_go_bro_house
        - buy_the_clothes
        - 
'''

# %%
'''
# 2022_11_15

    # 2022_11_15_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - find_thesises
            09:00 ~ 10:30 - ready_and_breakfirst
            10:30 ~ 12:00 - CJG_meeting
        
    # 2022_11_15_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 13:30 - LTB_meeting
            13:30 ~ 14:30 - total_design_meeting
            14:30 ~ 18:00 - Korean_literature_lecture   

    # 2022_11_15_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 24:00 - webots_tutorial
          
    # 2022_11_15_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - tire_wear_predict_human_NN_study
        - smart_phone_modeling_display
        - webot_e_puch_study
        - optimization_lecture_listen
        - how to connect with ros,webots,python
        - hyukpenhime_lecture
        - famliy_traviling_plan
        - PYS_meeting
        - total_design_meeting
        - buy_the_clothes
        - total_desing_presentation_perpare
        - send_email_golf_and_Korean
        - 
'''

# %%
'''
# 2022_11_16

    # 2022_11_16_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - webots_tutorial

    # 2022_11_16_second
        # 12:00 ~ 18:00
            12:00 ~ 12:30 - ready
            12:30 ~ 13:30 - lunch
            13:30 ~ 18:00 - optimization_lecutre_listen

    # 2022_11_16_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 21:00 - webots_tutorial_and_Chinese_lecture
            21:00 ~ 24:00 - webots_tutorial_or_optimization_lecutre_listen
            
    # 2022_11_16_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - tire_wear_predict_human_NN_study
        - smart_phone_modeling_display
        - webot_e_puch_study
        - optimization_lecture_listen
        - how to connect with ros,webots,python
        - hyukpenhime_lecture
        - famliy_traviling_plan
        - PYS_meeting
        - total_design_meeting
        - buy_the_clothes
        - total_desing_presentation_perpare
        - send_email_golf_and_Korean
        - 
'''

# %%
'''
# 2022_11_17

    # 2022_11_17_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - ready_and_breakfirst
            07:00 ~ 09:00 - PYS_meeting
            09:00 ~ 12:00 - optimization_lecture
            
    # 2022_11_17_second
        # 12:00 ~ 18:00
            12:00 ~ 13:30 - webots_study
            13:30 ~ 14:00 - lunch
            14:00 ~ 16:00 - ER_meeting
            16:00 ~ 18:00 - go_to_home

    # 2022_11_17_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - father_birthday_party

    # 2022_11_17_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - tire_wear_predict_human_NN_study
        - smart_phone_modeling_display
        - webot_e_puch_study
        - optimization_lecture_listen
        - how to connect with ros,webots,python
        - hyukpenhime_lecture
        - famliy_traviling_plan
        - PYS_meeting
        - total_design_meeting
        - buy_the_clothes
        - total_desing_presentation_perpare
        - send_email_golf_and_Korean
        - 
'''

# %%
'''
# 2022_11_18

    # 2022_11_18_first
        # 06:00 ~ 12:00
            06:00 ~ 12:00 - zzZ

    # 2022_11_18_second
        # 12:00 ~ 18:00
            12:00 ~ 18:00 - NamSan_date

    # 2022_11_18_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - NamSan_date

    # 2022_11_18_fourth
        # 24:00 ~ 06:00 
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - tire_wear_predict_human_NN_study
        - smart_phone_modeling_display
        - webot_e_puch_study
        - optimization_lecture_listen
        - how to connect with ros,webots,python
        - hyukpenhime_lecture
        - famliy_traviling_plan
        - total_design_meeting
        - total_desing_presentation_perpare
        - send_email_golf_and_Korean
        - 
'''

# %%
'''
# 2022_11_24

    # do_list
        - Graduate_school_search
        - english_plan
        - optimization_lecture_listen
        - hyukpenhime_lecture
        - famliy_traviling_plan
        - z_plip_analysis_and_improvement_design
        - honina_talk_research_student
        - e_puck_absolutely_distance_measure
        - ER_report_write
        - research_student_salary_time
        - Korean_literature_study
        - optimization_lecture_study
        - golf_study
        - ppt_make_z_plip
        - total_design_ppt_make_patent_find

'''

# %%
'''
# 2022_11_28

    # 2022_11_28_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 10:00 - total_design_presentation_prepare
            10:00 ~ 12:00 - optimalizeation_lecture
            

    # 2022_11_28_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - honina_breakfirst
            13:00 ~ 18:00 - smart_phone_lecture
            

    # 2022_11_28_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - honina_soccer_watch

    # 2022_11_28_fourth
        # 24:00 ~ 06:00 
            24:00 ~ 06:00 - zzZ
            
    # do_list
        - Graduate_school_search
        - english_plan
        - tire_wear_predict_human_NN_study
        - smart_phone_modeling_display
        - webot_e_puch_study
        - optimization_lecture_listen
        - how to connect with ros,webots,python
        - hyukpenhime_lecture
        - famliy_traviling_plan
        - total_design_meeting
        - total_desing_presentation_perpare
        - send_email_golf_and_Korean
        - 
'''
