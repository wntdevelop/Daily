# %%
'''
# 2022_08_16

    # 2022_08_16_first
        # 06:00 ~ 12:00
            06:00 ~ 06:30 - ready
            06:30 ~ 07:00 - breakfast
            07:00 ~ 08:50 - machine_learning_study
            09:00 ~ 12:00 - car_research
                09:00 ~ 09:30 - computer_setting
                09:30 ~ 11:00 - car_research
                11:00 ~ 12:00 - computer_assemble

    # 2022_08_16_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 14:00 - computer_assemble
            14:00 ~ 18:00 - car_research

    # 2022_08_16_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - girlfriend_call
            19:00 ~ 20:00 - dinner
            20:00 ~ 23:00 - machine_learning_study
            23:00 ~ 24:00 - english_listenling_study

    # 2022_08_16_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - sleep_zzZ


    # do_list
        - hair_cut_reservation
        - dental_clinic_reservation
        - 
  
'''

# %%
'''
# 2022_08_17

    # 2022_08_17_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - sleep
            07:00 ~ 07:30 - ready
            07:30 ~ 08:00 - breakfast
            08:00 ~ 08:50 - machine_learning_study
            09:00 ~ 12:00 - car_research
                09:00 ~ 10:00 - tire_wear_analysis_search
                10:00 ~ 11:00 - Body_Movement_Measurement_search
                11:00 ~ 12:00 - car_research

    # 2022_08_17_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - car_research

    # 2022_08_17_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 20:30 - car_research
            20:30 ~ 22:00 - girlfriend_call
            22:00 ~ 24:00 - car_drive 

    # 2022_08_17_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - sleep_zzZ


    # do_list
        - hair_cut_reservation
        - dental_clinic_reservation
        - coumputer_engineering_consultant
        - Graduate_school_search
        - shake_measure_equipment
        - analyze_project
'''

# %%
'''
# 2022_08_18

    # 2022_08_18_first
        # 06:00 ~ 12:00
            06:00 ~ 08:30 - sleep
            08:30 ~ 08:50 - ready
            09:00 ~ 12:00 - car_research
                09:00 ~ 10:00 - tire_wear_analysis_search
                10:00 ~ 11:00 - Body_Movement_Measurement_search
                11:00 ~ 12:00 - car_research

    # 2022_08_18_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - car_research
                13:00 ~ 15:00 - meeting_with_CJG
                15:00 ~ 18:00 - car_research

    # 2022_08_18_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 23:00 - analyze_project
            23:00 ~ 24:00 - analyze_meeting

    # 2022_08_18_fourth
        # 24:00 ~ 06:00
            24:00 ~ 06:00 - sleep_zzZ


    # do_list
        - coumputer_engineering_consultant
        - Graduate_school_search
        - shake_measure_equipment
        - send_email_question
        - analyze_project
        - CJG_project_produce_box_send_email
        - make_ppt_KTW
        - google_form_apply
        - english_plan
        - department_office_call
'''

# %%
'''
# 2022_08_19

    # 2022_08_19_first
        # 06:00 ~ 12:00
            06:00 ~ 08:00 - sleep
            08:00 ~ 08:50 - ready
            09:00 ~ 12:00 - car_research
                09:00 ~ 10:00 - VR_explore
                10:00 ~ 11:00 - coumputer_engineering_consultant
                11:00 ~ 12:00 - Body_Movement_Measurement_search

    # 2022_08_19_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - car_research

    # 2022_08_19_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - girlfriend_meet 

    # 2022_08_19_fourth
        # 24:00 ~ 06:00
            24:00 ~ 02:00 - girlfriend_call
            02:00 ~ 06:00 - sleep_zzZ


    # do_list
        - Graduate_school_search
        - shake_measure_equipment
        - send_email_question
        - CJG_project_produce_box_send_email
        - make_ppt_KTW
        - english_plan
        - department_office_call
        - oliv_young_enter
'''

# %%
'''
# 2022_08_20

    # 2022_08_20_first
        # 06:00 ~ 12:00
            06:00 ~ 10:00 - sleep
            10:00 ~ 11:00 - ready
            11:00 ~ 12:00 - breakfirst and lunch

    # 2022_08_20_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - hair_cut
            13:00 ~ 13:30 - olive_young
            13:30 ~ 14:00 - CJG_homepage
            14:00 ~ 14:30 - CJG_Payment request form
            14:30 ~ 16:00 - KTW_ppt
            16:00 ~ 17:00 - girlfriend_call
            17:00 ~ 18:00 - lol_game
            

    # 2022_08_20_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 20:00 - analyze_project
            20:00 ~ 22:00 - lol_game
            22:00 ~ 24:00 - lol_game 

    # 2022_08_20_fourth
        # 24:00 ~ 06:00
            24:00 ~ 01:00 - girlfriend_call
            01:00 ~ 06:00 - sleep_zzZ


    # do_list
        - Graduate_school_search
        - send_email_question
        - make_ppt_KTW
        - english_plan
        - ppt_presentation_prepare
        - someone_answer
'''

# %%
'''
# 2022_08_21

    # 2022_08_21_first
        # 06:00 ~ 12:00
            06:00 ~ 10:30 - sleep
            10:30 ~ 11:00 - ready
            11:00 ~ 12:00 - analyze_project

    # 2022_08_21_second
        # 12:00 ~ 18:00
            12:00 ~ 13:30 - analyze_project
            13:30 ~ 15:00 - analyze_project
            15:00 ~ 18:00 - girlfriend_meet
            

    # 2022_08_21_third
        # 18:00 ~ 24:00
            18:00 ~ 22:00 - girlfriend_meet
            22:00 ~ 24:00 - leave_and_analyze_project 
            

    # 2022_08_21_fourth
        # 24:00 ~ 06:00
            24:00 ~ 02:00 - girlfriend_call
            02:00 ~ 06:00 - sleep_zzZ


    # do_list
        - Graduate_school_search
        - send_email_question
        - make_ppt_KTW
        - english_plan
        - ppt_presentation_prepare
        - someone_answer
'''

# %%
'''
# 2022_08_22

    # 2022_08_22_first
        # 06:00 ~ 12:00
            06:00 ~ 07:00 - sleep
            07:00 ~ 07:30 - ready
            07:30 ~ 08:30 - cae_meeting
            08:30 ~ 09:30 - to work
            09:30 ~ 10:30 - coding_lecture_youtube_me_too_coding_machine_learning
            10:30 ~ 11:00 - ppt_presentation_prepare
            11:00 ~ 12:00 - auto_meeting
                        
    # 2022_08_22_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 16:00 - CJG_meeting
            16:00 ~ 15:30 - tire_wear_study
            15:30 ~ 18:00 - computer_assemble


    # 2022_08_22_third
        # 18:00 ~ 24:00
            18:00 ~ 18:30 - computer_assemble
            18:30 ~ 20:30 - girlfriend_call
            20:30 ~ 22:00 - coding_lecture 
            22:00 ~ 24:00 - girlfriend_call

    # 2022_08_22_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - sleep_zzZ


    # do_list
        - Graduate_school_search
        - send_email_question
        - english_plan
        - CJG_meeting
        - email_send_xsens
'''

# %%
'''
# 2022_08_23

    # 2022_08_23_first
        # 06:00 ~ 12:00
            06:00 ~ 06:40 - ready
            06:40 ~ 07:30 - cae_meeting
            07:30 ~ 08:30 - coding_lecture_youtube_me_too_coding_machine_learning
            08:30 ~ 09:30 - to work
            09:30 ~ 10:30 - file_submit
            10:30 ~ 12:00 - coding_lecture_youtube_me_too_coding_machine_learning

                           

    # 2022_08_23_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 14:00 - car_research
            14:00 ~ 16:00 - CJG_meeting
            16:00 ~ 18:00 - AGH_meeting


    # 2022_08_23_third
        # 18:00 ~ 24:00
            18:00 ~ 18:30 - dinner
            18:30 ~ 22:00 - coding_lecture_youtube_me_too_coding_machine_learning
            22:00 ~ 22:30 - call_parents
            22:30 ~ 23:00 - call_girlfriend
            23:00 ~ 24:00 - coding_lecture_youtube_me_too_coding_machine_learning


    # 2022_08_23_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - sleep_zzZ
            

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - deep_reinforcement_learning_book
        - call_mothion
'''

# %%
'''
# 2022_08_24

    # 2022_08_24_first
        # 06:00 ~ 12:00
            06:00 ~ 08:30 - zzZ
            08:30 ~ 08:50 - ready
            08:50 ~ 09:30 - breakfirst
            09:30 ~ 10:00 - to_work
            10:00 ~ 12:00 - cae_contest_thesis_read
                           

    # 2022_08_24_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - deep_reinforcement_learning_book_read


    # 2022_08_24_third
        # 18:00 ~ 24:00
            18:00 ~ 18:30 - dinner
            18:30 ~ 22:00 - deep_reinforcement_learning_book
            22:00 ~ 22:30 - call_parents
            22:30 ~ 23:00 - call_girlfriend
            23:00 ~ 24:00 - deep_reinforcement_learning_book_read


    # 2022_08_24_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - sleep_zzZ
            

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - book_read_103p
'''

# %%
'''
# 2022_08_25

    # 2022_08_25_first
        # 06:00 ~ 12:00
            06:00 ~ 06:30 - ready
            06:30 ~ 07:30 - CAE_contest_thesis_read
            07:30 ~ 08:30 - CAE_meeting
            08:30 ~ 08:50 - breakfirst
            08:50 ~ 09:00 - to_work
            09:00 ~ 12:00 - deep_reinforcement_learning_book_read
                           

    # 2022_08_25_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 14:00 - deep_reinforcement_learning_book_read
            14:00 ~ 16:00 - CJG_meeting
            16:00 ~ 18:00 - deep_reinforcement_learning_book_read


    # 2022_08_25_third
        # 18:00 ~ 24:00
            18:00 ~ 18:30 - dinner
            18:30 ~ 22:00 - deep_reinforcement_learning_book
            22:00 ~ 22:30 - call_parents
            22:30 ~ 23:00 - call_girlfriend
            23:00 ~ 24:00 - deep_reinforcement_learning_book_read


    # 2022_08_25_fourth
        # 24:00 ~ 06:00
            00:00 ~ 05:00 - CJG_coding_excel
            05:00 ~ 06:00 - sleep_zzZ
            

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - book_read_103p
        - 
'''

# %%
'''
# 2022_08_26

    # 2022_08_26_first
        # 06:00 ~ 12:00
            06:00 ~ 09:00 - zzZ
            09:00 ~ 10:00 - ready
            09:00 ~ 12:00 - workshop
                           

    # 2022_08_26_second
        # 12:00 ~ 18:00
            12:00 ~ 18:00 - workshop

    # 2022_08_26_third
        # 18:00 ~ 24:00
            18:00 ~ 24:00 - girlfriend_date


    # 2022_08_26_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - go_to_home
            02:00 ~ 06:00 - go_to_home
            
            

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - book_read_103p
        - 
'''

# %%
'''
# 2022_08_27

    # 2022_08_27_first
        # 06:00 ~ 12:00
            06:00 ~ 09:30 - zzZ
            09:30 ~ 10:00 - ready
            10:00 ~ 12:00 - CJG_excel_work
                           

    # 2022_08_27_second
        # 12:00 ~ 18:00
            12:00 ~ 14:00 - CJG_excel_work
            14:00 ~ 15:00 - lunch
            15:00 ~ 17:00 - study_paln
            17:00 ~ 18:00 - zzZ

    # 2022_08_27_third
        # 18:00 ~ 24:00
            18:00 ~ 20:00 - zzZ
            20:00 ~ 22:00 - dinner
            22:00 ~ 24:00 - game_lol
            


    # 2022_08_27_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - girlfriend_call
            02:00 ~ 06:00 - zzZ
            
            

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - book_read_103p
        - meeting_fee_claim
'''

# %%
'''
# 2022_08_28

    # 2022_08_28_first
        # 06:00 ~ 12:00
            06:00 ~ 09:30 - zzZ
            09:30 ~ 12:00 - game_lol
                           

    # 2022_08_28_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 14:00 - ready
            14:00 ~ 16:00 - deep_reinforcement_learning_book_read
            16:00 ~ 18:00 - grilfriend_meet

    # 2022_08_28_third
        # 18:00 ~ 24:00
            18:00 ~ 23:00 - grilfriend_meet
            23:00 ~ 24:00 - come_back_home
            


    # 2022_08_28_fourth
        # 24:00 ~ 06:00
            00:00 ~ 01:00 - wash
            01:00 ~ 06:00 - zzZ
            
            

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - book_read_103p
        - meeting_fee_claim
        - zig_get
'''

# %%
'''
# 2022_08_29

    # 2022_08_29_first
        # 06:00 ~ 12:00
            06:00 ~ 09:30 - zzZ
            09:30 ~ 10:20 - ready
            10:20 ~ 10:50 - CJG_meeting
            10:50 ~ 11:00 - zig_get
            11:00 ~ 12:00 - KTW_meeting            
                           

    # 2022_08_29_second
        # 12:00 ~ 18:00
            12:00 ~ 12:10 - zig_make
            12:10 ~ 12:50 - lunch
            12:50 ~ 13:00 - zig_get
            13:00 ~ 14:00 - deep_reinforcement_learning_book_read
            14:00 ~ 15:00 - KTW_meeting
            15:00 ~ 16:00 - film_attach
            16:00 ~ 18:00 - deep_reinforcement_learning_book_read
            


    # 2022_08_29_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - dinner
            19:00 ~ 20:00 - youtube_RL
            20:00 ~ 23:00 - deep_reinforcement_learning_book_read
            23:00 ~ 24:00 - girl_friend_call


    # 2022_08_29_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
            
            

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - book_read_103p
        - meeting_fee_claim
        - zig_get
'''

# %%
'''
# 2022_08_30

    # 2022_08_30_first
        # 06:00 ~ 12:00
            06:00 ~ 06:30 - zzZ
            06:30 ~ 07:00 - breakfirst
            07:00 ~ 07:20 - ready
            07:20 ~ 08:00 - deep_reinforcement_learning_book_read
            08:00 ~ 08:30 - LOL_game
            08:30 ~ 08:50 - ppt_make
            08:50 ~ 12:00 - car_research        
                           

    # 2022_08_30_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - car_research
            


    # 2022_08_30_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - car_research
            19:00 ~ 20:00 - dinner
            20:00 ~ 23:30 - deep_reinforcement_learning_book_read
            23:30 ~ 24:00 - girl_friend_call


    # 2022_08_30_fourth
        # 24:00 ~ 06:00
            00:00 ~ 02:00 - girl_friend_call
            00:00 ~ 06:00 - zzZ
       

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - book_read_103p
        - meeting_fee_claim
        - zig_get
        - cae_how_to_do
'''

# %%
'''
# 2022_08_31

    # 2022_08_31_first
        # 06:00 ~ 12:00
            06:00 ~ 07:30 - zzZ
            07:30 ~ 08:00 - ready
            08:00 ~ 08:50 - deep_reinforcement_learning_book_read
            08:50 ~ 12:00 - car_research        
                           

    # 2022_08_31_second
        # 12:00 ~ 18:00
            12:00 ~ 13:00 - lunch
            13:00 ~ 18:00 - car_research
            

    # 2022_08_31_third
        # 18:00 ~ 24:00
            18:00 ~ 19:00 - car_research
            19:00 ~ 20:00 - dinner
            20:00 ~ 21:00 - deep_reinforcement_learning_book_read
            21:00 ~ 24:00 - girlfriend_meet


    # 2022_08_31_fourth
        # 24:00 ~ 06:00
            00:00 ~ 06:00 - zzZ
            
            

    # do_list
        - Graduate_school_search
        - english_plan
        - computer_assemble
        - book_read_103p
        - meeting_fee_claim
        - cae_how_to_do


        
'''
